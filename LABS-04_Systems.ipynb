# %% [markdown]
# # LABS-4: Systems Project
#
# In this notebook you will run a few cells to ensure that your environment is properly set up.

# %%
## First cell
# run this for step 13 in your instructions

print("Hello, World!")
# Out:
# Hello, World!

# %%
## Second cell
# run this for step 19 in your instructions
import pandas as pd

# %%
## Part 3: Accessing your data
# Load raw IMDb data
data = pd.read_csv("data/raw/imdb_movies.csv")
data.head()
# Out:
#                          names       date_x  score  ...     budget_x       revenue country
# 0                    Creed III  03/02/2023    73.0  ...   75000000.0  2.716167e+08      AU
# 1     Avatar: The Way of Water  12/15/2022    78.0  ...  460000000.0  2.316795e+09      AU
# 2  The Super Mario Bros. Movie  04/05/2023    76.0  ...  100000000.0  7.244590e+08      AU
# 3                      Mummies  01/05/2023    70.0  ...   12300000.0  3.420000e+07      AU
# 4                    Supercell  03/17/2023    61.0  ...   77000000.0  3.409420e+08      US
#
# [5 rows x 12 columns]
